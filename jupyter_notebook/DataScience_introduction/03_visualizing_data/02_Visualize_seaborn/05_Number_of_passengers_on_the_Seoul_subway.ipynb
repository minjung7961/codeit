# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

df = pd.read_csv('data/subway.csv')
df
# Out:
#     line station     in    out
# 0    중앙선      지평     37     28
# 1    중앙선      용문   2064   2103
# 2    중앙선      원덕    375    357
# 3    중앙선      양평   4338   4378
# 4    중앙선      오빈    321    321
# ..   ...     ...    ...    ...
# 586  1호선    종로5가  31245  30678
# 587  1호선    종로3가  38099  36928
# 588  1호선      종각  52310  50088
# 589  1호선      시청  29150  29043
# 590  1호선     서울역  58391  54356
#
# [591 rows x 4 columns]

# %%
df['in']
# Out:
# 0         37
# 1       2064
# 2        375
# 3       4338
# 4        321
#        ...
# 586    31245
# 587    38099
# 588    52310
# 589    29150
# 590    58391
# Name: in, Length: 591, dtype: int64

# %%
# df.set_index('in',inplace=True)

# %%
df
# Out:
#     line station     in    out
# 0    중앙선      지평     37     28
# 1    중앙선      용문   2064   2103
# 2    중앙선      원덕    375    357
# 3    중앙선      양평   4338   4378
# 4    중앙선      오빈    321    321
# ..   ...     ...    ...    ...
# 586  1호선    종로5가  31245  30678
# 587  1호선    종로3가  38099  36928
# 588  1호선      종각  52310  50088
# 589  1호선      시청  29150  29043
# 590  1호선     서울역  58391  54356
#
# [591 rows x 4 columns]

# %%
df.tail(60)
# Out:
#     line       station      in     out
# 531  2호선     용두(동대문구청)    2691    2713
# 532  2호선         신정네거리   10436   10895
# 533  2호선          양천구청    7713    8227
# 534  2호선           도림천    1371    1478
# 535  2호선           신설동    4374    4266
# 536  2호선            신답    1786    2073
# 537  2호선            용답    2794    2788
# 538  2호선    충정로(경기대입구)   12512   13431
# 539  2호선            아현   11595   11318
# 540  2호선            이대   18395   19081
# 541  2호선            신촌   49993   50404
# 542  2호선          홍대입구   75939   79039
# 543  2호선            합정   35163   36838
# 544  2호선            당산   24385   26976
# 545  2호선         영등포구청   26347   26422
# 546  2호선            문래   23945   24189
# 547  2호선           신도림   61584   59927
# 548  2호선      대림(구로구청)   31068   31845
# 549  2호선       구로디지털단지   73789   73729
# 550  2호선           신대방   30896   29617
# 551  2호선            신림   75705   74440
# 552  2호선            봉천   27886   26217
# 553  2호선   서울대입구(관악구청)   57897   56596
# ...

# %%
df.plot(kind='bar',y = 'in')
# Out:
# <AxesSubplot:>

# %%
df['in'].value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(df['in'])
# Out:
# <AxesSubplot:>
