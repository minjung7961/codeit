# %%
# %matplotlib inline
import pandas as pd
import seaborn as sns

body_df = pd.read_csv('data/body.csv')
body_df
# Out:
#      Number  Height  Weight
# 0         1   176.0    85.2
# 1         2   175.3    67.7
# 2         3   168.6    75.2
# 3         4   168.1    67.1
# 4         5   175.3    63.0
# ..      ...     ...     ...
# 995     996   171.8    68.2
# 996     997   171.5    75.6
# 997     998   177.9    66.5
# 998     999   174.4    72.0
# 999    1000   173.5    77.4
#
# [1000 rows x 3 columns]

# %%
body_df.plot(kind='scatter',x='Height', y='Weight')
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Weight'>

# %% [markdown]
# 키와 몸무개가 꾀나 연관이 있어보인다 만약그렇다면 키만가지고 몸무개를 예측할수있을까? 어느정도는 가능할 것이다
# seaborn 라이브러리가 도와줄것이다

# %%
sns.lmplot(data=body_df,x='Height', y ='Weight')

# %% [markdown]
# 중간에 생긴점은 회귀선(Lahaina noon)이라고 한다
