# %%
import pandas as pd

df = pd.read_csv('data/enrolment_3.csv')

# 코드를 작성하세요.

# 정답 출력
df.rename(columns={'room assignment':'room number'},inplace = True)
df.head(60)
# Out:
#          id  year                   course name       status   room number
# 0   2777729     1                       science      allowed    Auditorium
# 1   2777730     2                       science      allowed    Auditorium
# 2   2777765     1                          arts      allowed    Auditorium
# 3   2777766     2                          arts      allowed    Auditorium
# 4   2777785     1                           mba      allowed    Small room
# 5   2777786     2                           mba      allowed    Small room
# 6   2777793     1                 mba 2nd shift  not allowed  not assigned
# 7   2777794     2                 mba 2nd shift  not allowed  not assigned
# 8   2777795     1                 mca 2nd shift  not allowed  not assigned
# 9   2777796     2                 mca 2nd shift  not allowed  not assigned
# 10  2777797     3                 mca 2nd shift  not allowed  not assigned
# ...

# %%
a_bool = df['status'] == 'allowed'

# %%
a_df = df[a_bool]
a_df
# Out:
#            id  year           course name   status  room number
# 0     2777729     1               science  allowed   Auditorium
# 1     2777730     2               science  allowed   Auditorium
# 2     2777765     1                  arts  allowed   Auditorium
# 3     2777766     2                  arts  allowed   Auditorium
# 4     2777785     1                   mba  allowed   Small room
# ...       ...   ...                   ...      ...          ...
# 1995  2796805     3  computer application  allowed  Medium room
# 1996  2796812     1               nursing  allowed  Medium room
# 1997  2796813     2               nursing  allowed  Medium room
# 1998  2796814     3               nursing  allowed  Medium room
# 1999  2796815     4               nursing  allowed  Medium room
#
# [1448 rows x 5 columns]

# %%
room_array = df.loc[a_bool,'room number'].unique()
room_array
# Out:
# array(['Auditorium', 'Small room', 'Medium room', 'Large room'],
#       dtype=object)

# %%
room_list[0]
# Out:
# 'Auditorium'

# %%
a_Audi_bool = a_df['room number'] == 'Auditorium'
a_Audi_bool
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4       False
#         ...
# 1995    False
# 1996    False
# 1997    False
# 1998    False
# 1999    False
# Name: room number, Length: 1448, dtype: bool

# %%
audi_lec = a_df.loc[a_Audi_bool,'course name']
audi_lec_uniq = audi_lec.unique()
audi_lec_uniq.sort()
audi_lec_uniq
# Out:
# array(['arts', 'commerce', 'science'], dtype=object)

# %%
audi_lec
# Out:
# 0       science
# 1       science
# 2          arts
# 3          arts
# 35         arts
#          ...
# 1862    science
# 1863    science
# 1914       arts
# 1915       arts
# 1916       arts
# Name: course name, Length: 383, dtype: object

# %%
for i in range(len(audi_lec_uniq)):
    df.loc[df['course name'] == audi_lec_uniq[i],'room number'] = f'Auditorium-{i+1}'

df.head(60)
# Out:
#          id  year                   course name       status   room number
# 0   2777729     1                       science      allowed  Auditorium-3
# 1   2777730     2                       science      allowed  Auditorium-3
# 2   2777765     1                          arts      allowed  Auditorium-1
# 3   2777766     2                          arts      allowed  Auditorium-1
# 4   2777785     1                           mba      allowed    Small room
# 5   2777786     2                           mba      allowed    Small room
# 6   2777793     1                 mba 2nd shift  not allowed  not assigned
# 7   2777794     2                 mba 2nd shift  not allowed  not assigned
# 8   2777795     1                 mca 2nd shift  not allowed  not assigned
# 9   2777796     2                 mca 2nd shift  not allowed  not assigned
# 10  2777797     3                 mca 2nd shift  not allowed  not assigned
# ...

# %%
df
# Out:
#            id  year           course name   status  room number
# 0     2777729     1               science  allowed   Auditorium
# 1     2777730     2               science  allowed   Auditorium
# 2     2777765     1                  arts  allowed   Auditorium
# 3     2777766     2                  arts  allowed   Auditorium
# 4     2777785     1                   mba  allowed   Small room
# ...       ...   ...                   ...      ...          ...
# 1995  2796805     3  computer application  allowed  Medium room
# 1996  2796812     1               nursing  allowed  Medium room
# 1997  2796813     2               nursing  allowed  Medium room
# 1998  2796814     3               nursing  allowed  Medium room
# 1999  2796815     4               nursing  allowed  Medium room
#
# [2000 rows x 5 columns]
