# %%
import pandas as pd

# %%
s_df = pd.read_csv('data/samsong.csv')
h_df = pd.read_csv('data/hyundee.csv')
d = {
    'day' : s_df['요일'],
    'samsong' : s_df['문화생활비'],
    'hyundee' : h_df['문화생활비']
}
df = pd.DataFrame(d)
df
# Out:
#    day  samsong  hyundee
# 0  MON     4308     5339
# 1  TUE     7644     3524
# 2  WED     5674     5364
# 3  THU     8621     9942
# 4  FRI    23052    33511
# 5  SAT    15330    19397
# 6  SUN    19030    19925
